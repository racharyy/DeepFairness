# %%
import pandas as pd
import pickle

# %%
with open('../../Data/data_dict_fixed.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
df.keys()
# Out:
# dict_keys(['view', 'transcript', 'rating', 'a', 'total_count', 'Video_ID'])

# %%
rating_dict = df['rating']

# %%
rating_dict
# Out:
# [[0.01967435549525102,
#   0.02103120759837178,
#   0.04748982360922659,
#   0.04511533242876527,
#   0.18487109905020352,
#   0.15094979647218454,
#   0.019335142469470826,
#   0.14009497964721845,
#   0.03934871099050204,
#   0.038331071913161464,
#   0.04477611940298507,
#   0.06886024423337857,
#   0.0912483039348711,
#   0.08887381275440977],
#  [0.004558404558404558,
#   0.015954415954415956,
#   0.017663817663817662,
#   0.04843304843304843,
#   0.03076923076923077,
#   0.4301994301994302,
#   0.017663817663817662,
#   0.08603988603988603,
#   0.035327635327635325,
#   0.004558404558404558,
#   0.007977207977207978,
#   0.07578347578347579,
#   0.1903133903133903,
#   0.034757834757834755],
#  [0.01840056617126681,
#   0.020523708421797595,
#   0.01132342533616419,
#   0.2781316348195329,
#   0.027600849256900213,
#   0.18400566171266808,
#   0.18259023354564755,
#   0.07643312101910828,
#   0.11535739561217269,
#   0.014154281670205236,
#   0.005661712668082095,
# ...
