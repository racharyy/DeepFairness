# %%
import pandas as pd

# %%
df_1 = pd.read_csv('index.csv')

# %%
df_2 = pd.read_csv('id_url.csv')

# %%
df_2.head()
# Out:
#    Video_ID                                                url
# 0         1  https://www.ted.com/talks/al_gore_on_averting_...
# 1        10  https://www.ted.com/talks/dean_ornish_on_the_w...
# 2      1000         https://www.ted.com/talks/gero_miesenboeck
# 3      1001  https://www.ted.com/talks/andrew_bird_s_one_ma...
# 4      1002  https://www.ted.com/talks/emily_pilloton_teach...

# %%
df_1.head()
# Out:
#    Video_ID                                             Title  beautiful  \
# 0      1819  3 reasons we still haven’t gotten rid of malaria          7
# 1      2365          Art that lets you talk back to NSA spies         15
# 2      2451                               The gospel of doubt        666
# 3       831            How art gives shape to cultural change         63
# 4      1736              Learn to read Chinese ... with ease!        175
#
#    funny  ingenious  ok  fascinating  total_count  persuasive  inspiring  \
# 0      4         18  30           43          601         142         55
# 1     62         61  35           42          596          28        114
# 2     97        104  48          206         3440         311       1121
# 3      1         16  77           49          671          29        125
# 4    510        638  91          567         3704         111        403
#
#       ...      confusing  courageous  unconvincing  Totalviews  \
# ...

# %%
result = pd.merge(df_1, df_2, on = 'Video_ID')

# %%
result.head()
# Out:
#    Video_ID                                             Title  beautiful  \
# 0      1819  3 reasons we still haven’t gotten rid of malaria          7
# 1      2365          Art that lets you talk back to NSA spies         15
# 2      2451                               The gospel of doubt        666
# 3       831            How art gives shape to cultural change         63
# 4      1736              Learn to read Chinese ... with ease!        175
#
#    funny  ingenious  ok  fascinating  total_count  persuasive  inspiring  \
# 0      4         18  30           43          601         142         55
# 1     62         61  35           42          596          28        114
# 2     97        104  48          206         3440         311       1121
# 3      1         16  77           49          671          29        125
# 4    510        638  91          567         3704         111        403
#
#                          ...                          courageous  \
# ...
